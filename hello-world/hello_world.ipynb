# %%
import pandas as pd
import altair as alt
import datapane as dp

dataset = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv')

# %%
dataset.location.unique()
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Anguilla', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Armenia',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Bonaire Sint Eustatius and Saba',
#        'Burkina Faso', 'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada', 'Switzerland', 'Chile',
#        'China', "Cote d'Ivoire", 'Cameroon',
#        'Democratic Republic of Congo', 'Congo', 'Colombia', 'Comoros',
#        'Cape Verde', 'Costa Rica', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Dominica',
#        'Denmark', 'Dominican Republic', 'Algeria', 'Ecuador', 'Egypt',
#        'Eritrea', 'Western Sahara', 'Spain', 'Estonia', 'Ethiopia',
# ...

# %%
# Choose your countries from above! 
countries = ['Brazil', 'New Zealand', 'Iran']
df = dataset[dataset.location.isin(countries)]

# %%
dataset.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_per_case', 'positive_rate', 'tests_units', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
base = alt.Chart(df).encode(x='date:T', color='location').mark_area(opacity=0.5, stroke='black').interactive().properties(width='container')
c1 = base.encode(y='new_cases_smoothed_per_million')
c2 = base.encode(y='new_deaths_smoothed_per_million')

# %%
c3 = base.encode(y='total_deaths_per_million:Q').properties(width='container')

# %%
df
# Out:
#      iso_code      continent location        date  total_cases  new_cases  \
# 6119      BRA  South America   Brazil  2019-12-31          0.0        0.0
# 6120      BRA  South America   Brazil  2020-01-01          0.0        0.0
# 6121      BRA  South America   Brazil  2020-01-02          0.0        0.0
# 6122      BRA  South America   Brazil  2020-01-03          0.0        0.0
# 6123      BRA  South America   Brazil  2020-01-04          0.0        0.0
# ...       ...            ...      ...         ...          ...        ...
# 6391      BRA  South America   Brazil  2020-09-28    4732309.0    14318.0
# 6392      BRA  South America   Brazil  2020-09-29    4745464.0    13155.0
# 6393      BRA  South America   Brazil  2020-09-30    4777522.0    32058.0
# 6394      BRA  South America   Brazil  2020-10-01    4810935.0    33413.0
# 6395      BRA  South America   Brazil  2020-10-02    4847092.0    36157.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
import datapane
dp.Report(
  dp.Table(df, caption=f'Dataset for {countries}'),
  dp.Blocks(dp.Plot(c1), dp.Plot(c2), columns=2),
  dp.Plot(c3, caption='Total deaths per million')
).publish('covid_report', open=True)
# Out:
# Publishing report and associated data - please wait..
# Report successfully published at https://acme.datapane.net/leo/reports/covid_report/
# ''
